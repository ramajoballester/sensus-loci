# %%
import numpy as np
from pypcd import pypcd
import os
def pcd2bin(pcd_file, bin_file):
    pcd_data = pypcd.PointCloud.from_path(pcd_file)
    points = np.zeros([pcd_data.width, 4], dtype=np.float32)
    points[:, 0] = pcd_data.pc_data['x'].copy()
    points[:, 1] = pcd_data.pc_data['y'].copy()
    points[:, 2] = pcd_data.pc_data['z'].copy()
    points[:, 3] = pcd_data.pc_data['intensity'].copy().astype(np.float32)
    with open(bin_file, 'wb') as f:
        f.write(points.tobytes())

# %%
def transform_files(source_dir, dest_dir):
    try:
        # Create destination directory if it doesn't exist
        if not os.path.exists(dest_dir):
            os.makedirs(dest_dir)

        # Iterate through files in source directory
        for file_name in os.listdir(source_dir):
            # Construct source and destination file paths
            src_path = os.path.join(source_dir, file_name)
            dest_path = os.path.join(dest_dir, file_name.replace('.pcd', '.bin'))

            # Copy file to destination directory
            pcd2bin(src_path, dest_path)
            print(f"File '{dest_path}' transformed to '{dest_dir}'")

        print("All files converted successfully.")
    except Exception as e:
        print(f"Error: {e}")

# %%
transform_files('/home/javier/datasets/DAIR/single-infrastructure-side-velodyne', '/home/javier/datasets/DAIR/single-infrastructure-side-mmdet/points')
# Out:
# File '/home/javier/datasets/DAIR/single-infrastructure-side-mmdet/points/008086.bin' transformed to '/home/javier/datasets/DAIR/single-infrastructure-side-mmdet/points'
# File '/home/javier/datasets/DAIR/single-infrastructure-side-mmdet/points/009952.bin' transformed to '/home/javier/datasets/DAIR/single-infrastructure-side-mmdet/points'
# File '/home/javier/datasets/DAIR/single-infrastructure-side-mmdet/points/009655.bin' transformed to '/home/javier/datasets/DAIR/single-infrastructure-side-mmdet/points'
# File '/home/javier/datasets/DAIR/single-infrastructure-side-mmdet/points/002330.bin' transformed to '/home/javier/datasets/DAIR/single-infrastructure-side-mmdet/points'
# File '/home/javier/datasets/DAIR/single-infrastructure-side-mmdet/points/008224.bin' transformed to '/home/javier/datasets/DAIR/single-infrastructure-side-mmdet/points'
# ...
